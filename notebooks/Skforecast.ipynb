# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from skforecast.ForecasterAutoreg import ForecasterAutoreg
from skforecast.ForecasterAutoregCustom import ForecasterAutoregCustom
from skforecast.ForecasterAutoregDirect import ForecasterAutoregDirect
from skforecast.model_selection import grid_search_forecaster
from skforecast.model_selection import backtesting_forecaster
from skforecast.utils import save_forecaster
from skforecast.utils import load_forecaster

import warnings
warnings.filterwarnings("ignore")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_36725/940481639.py in <module>
#       4 import seaborn as sns
#       5
# ----> 6 from skforecast.ForecasterAutoreg import ForecasterAutoreg
#       7 from skforecast.ForecasterAutoregCustom import ForecasterAutoregCustom
#       8 from skforecast.ForecasterAutoregDirect import ForecasterAutoregDirect
#
# ModuleNotFoundError: No module named 'skforecast'

# %%
# DATA PATH
TRAIN_DATA_PATH = os.path.join("..","datasets","processed","train.csv")
TEST_DATA_PATH = os.path.join("..","datasets","processed","test.csv")

# %%
train = pd.read_csv(TRAIN_DATA_PATH, parse_dates=['Month'], index_col='Month', squeeze=True)
test = pd.read_csv(TEST_DATA_PATH, parse_dates=['Month'], index_col='Month', squeeze=True)

# %%
plt.figure(figsize=(12,4))
plt.title("Train-Test")
train.plot()
test.plot()
plt.show()

# %%
# !pip install skforecast
# Out:
# Collecting skforecast
#   Downloading skforecast-0.6.0-py2.py3-none-any.whl (216 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 217.0/217.0 kB 970.6 kB/s eta 0:00:00 kB/s eta 0:00:01:01
# Requirement already satisfied: pandas<1.6,>=1.2 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from skforecast) (1.4.2)
# Collecting scikit-optimize==0.9.0
#   Downloading scikit_optimize-0.9.0-py2.py3-none-any.whl (100 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.3/100.3 kB 4.5 MB/s eta 0:00:00
# Requirement already satisfied: joblib<1.3.0,>=1.1.0 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from skforecast) (1.1.0)
# Collecting optuna<3.1,>=2.10.0
#   Downloading optuna-3.0.6-py3-none-any.whl (348 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 348.6/348.6 kB 4.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: scikit-learn<1.2,>=1.0 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from skforecast) (1.1.1)
# Collecting tqdm<4.65,>=4.57.0
#   Using cached tqdm-4.64.1-py2.py3-none-any.whl (78 kB)
# Requirement already satisfied: numpy<1.24,>=1.20 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from skforecast) (1.22.4)
# Requirement already satisfied: scipy>=0.19.1 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from scikit-optimize==0.9.0->skforecast) (1.8.1)
# Collecting pyaml>=16.9
#   Downloading pyaml-21.10.1-py2.py3-none-any.whl (24 kB)
# Collecting alembic>=1.5.0
#   Downloading alembic-1.10.2-py3-none-any.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 8.1 MB/s eta 0:00:00
# Collecting colorlog
#   Downloading colorlog-6.7.0-py2.py3-none-any.whl (11 kB)
# Collecting cliff
#   Downloading cliff-4.2.0-py3-none-any.whl (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata<5.0.0 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from optuna<3.1,>=2.10.0->skforecast) (4.12.0)
# Collecting sqlalchemy>=1.3.0
#   Downloading SQLAlchemy-2.0.6-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 6.4 MB/s eta 0:00:006.8 MB/s eta 0:00:01
# Requirement already satisfied: packaging>=20.0 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from optuna<3.1,>=2.10.0->skforecast) (21.3)
# Collecting PyYAML
#   Using cached PyYAML-6.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (701 kB)
# Collecting cmaes>=0.8.2
#   Downloading cmaes-0.9.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from pandas<1.6,>=1.2->skforecast) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from pandas<1.6,>=1.2->skforecast) (2.8.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from scikit-learn<1.2,>=1.0->skforecast) (3.1.0)
# Collecting importlib-resources
#   Downloading importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting Mako
#   Downloading Mako-1.2.4-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.7/78.7 kB 4.2 MB/s eta 0:00:00
# Collecting typing-extensions>=4
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Requirement already satisfied: zipp>=0.5 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from importlib-metadata<5.0.0->optuna<3.1,>=2.10.0->skforecast) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from packaging>=20.0->optuna<3.1,>=2.10.0->skforecast) (3.0.9)
# Requirement already satisfied: six>=1.5 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas<1.6,>=1.2->skforecast) (1.16.0)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (618 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.5/618.5 kB 6.3 MB/s eta 0:00:007.3 MB/s eta 0:00:01
# Collecting PrettyTable>=0.7.2
#   Downloading prettytable-3.6.0-py3-none-any.whl (27 kB)
# Collecting autopage>=0.4.0
#   Downloading autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting cmd2>=1.0.0
#   Downloading cmd2-2.4.3-py3-none-any.whl (147 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.2/147.2 kB 5.2 MB/s eta 0:00:00
# Collecting stevedore>=2.0.1
#   Downloading stevedore-5.0.0-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 2.9 MB/s eta 0:00:00
# Collecting wcwidth>=0.1.7
#   Downloading wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Requirement already satisfied: attrs>=16.3.0 in /home/pablo/Documentos/DATA SCIENCE/Projects/Portafolio/airline_passengers/airpass_env/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna<3.1,>=2.10.0->skforecast) (22.2.0)
# Collecting pyperclip>=1.6
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pbr!=2.1.0,>=2.0.0
#   Downloading pbr-5.11.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 5.2 MB/s eta 0:00:00
